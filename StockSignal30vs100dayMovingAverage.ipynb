# %% [markdown]
# <a href="https://colab.research.google.com/github/brewerk/Hello-World/blob/master/StockSignal30vs100dayMovingAverage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Description: This program uses the dual moving average crossover to determine when to buy and sell stock

# %%
#Import the libraries
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
#load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a49608b7-8b79-4182-ae0b-a8468fd2bad8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a49608b7-8b79-4182-ae0b-a8468fd2bad8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving APPL2.csv to APPL2 (1).csv

# %%
#store the data
APPL = pd.read_csv('APPL2.csv')
#show the data
APPL
# Out:
#           Date    Open    High     Low   Close    Volume  Adj Close
# 0     14/10/08  116.26  116.40  103.14  104.08  70749800     104.08
# 1     13/10/08  104.55  110.53  101.02  110.26  54967000     110.26
# 2     10/10/08   85.70  100.00   85.00   96.80  79260700      96.80
# 3     09/10/08   93.35   95.80   86.60   88.74  57763700      88.74
# 4     08/10/08   85.91   96.33   85.68   89.79  78847900      89.79
# ...        ...     ...     ...     ...     ...       ...        ...
# 6076  13/09/84   27.50   27.62   27.50   27.50   7429600       3.14
# 6077  12/09/84   26.87   27.00   26.12   26.12   4773600       2.98
# 6078  11/09/84   26.62   27.37   26.62   26.87   5444000       3.07
# 6079  10/09/84   26.50   26.62   25.87   26.37   2346400       3.01
# 6080  07/09/84   26.50   26.87   26.25   26.50   2981600       3.02
#
# [6081 rows x 7 columns]

# %%
#Visualise the data
plt.figure(figsize=(12.5,4.5))
plt.plot(APPL['Adj Close'], label = 'APPL')
plt.title('Apple Adj. Close Price History')
plt.xlabel('Sep. 07, 1984 - Oct. 14, 2008')
plt.ylabel('Adj. Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()

# %%
#create the simple moving average with a 30 day window
SMA30 = pd.DataFrame()
SMA30['Adj Close'] = APPL['Adj Close'].rolling(window=30).mean()
SMA30
# Out:
#       Adj Close
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 6076   2.921667
# 6077   2.921000
# 6078   2.924333
# 6079   2.928333
# 6080   2.931667
#
# [6081 rows x 1 columns]

# %%
#Create a simple moving 100 day average
SMA100 = pd.DataFrame()
SMA100['Adj Close'] = APPL['Adj Close'].rolling(window=100).mean()
SMA100
# Out:
#       Adj Close
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 6076     3.0145
# 6077     3.0109
# 6078     3.0089
# 6079     3.0059
# 6080     3.0020
#
# [6081 rows x 1 columns]

# %%
#Visualise the data
#Visualise the data
plt.figure(figsize=(12.5,4.5))
plt.plot(APPL['Adj Close'], label = 'APPL')
plt.plot(SMA30['Adj Close'], label = 'SMA30')
plt.plot(SMA100['Adj Close'], label = 'SMA100')
plt.title('Apple Adj. Close Price History')
plt.xlabel('Sep. 07, 1984 - Oct. 14, 2008')
plt.ylabel('Adj. Close Price USD ($)')
plt.legend(loc='upper left')
plt.show()
